# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshbaba/OpenCV_Projects/blob/main/image_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#getting an image using web get
# !wget '/content/WhatsApp Image 2022-02-28 at 10.42.20 PM.jpeg'
# Out:
# /content/WhatsApp Image 2022-02-28 at 10.42.20 PM.jpeg: Scheme missing.

# %%
#libraries that can be used for image processing
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#loading an image through matplotlib.image module
img=mpimg.imread('/content/WhatsApp Image 2022-02-28 at 10.42.20 PM.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (200, 200, 3)

# %%
print(img)
# Out:
# [[[191 180 162]
#   [191 180 162]
#   [191 180 162]
#   ...
#   [196 179 151]
#   [195 178 150]
#   [195 178 150]]
#
#  [[191 180 162]
#   [191 180 162]
#   [191 180 162]
#   ...
#   [194 177 149]
#   [194 177 149]
#   [193 176 148]]
#
#  [[192 179 162]
#   [192 179 162]
#   [192 179 162]
#   ...
#   [192 175 145]
#   [192 175 145]
#   [192 175 145]]
#
#  ...
#
#  [[187 186 182]
#   [187 186 182]
#   [187 186 182]
#   ...
#   [185 176 167]
#   [183 174 165]
#   [182 173 164]]
#
#  [[185 184 180]
#   [185 184 180]
#   [186 185 181]
#   ...
#   [182 173 164]
#   [182 173 164]
#   [183 174 165]]
#
#  [[187 186 182]
#   [187 186 182]
#   [187 186 182]
#   ...
#   [183 174 165]
#   [186 177 168]
#   [189 180 171]]]

# %%
img_plot = plt.imshow(img)

# %%
# resizing the image using pillow libraray
from PIL import Image

# %%
img =Image.open('/content/WhatsApp Image 2022-02-28 at 10.42.20 PM.jpeg')

# %%
img_resized = img.resize((300,300))

# %%
img_resized.save('/content/WhatsApp Image 2022-02-28 at 10.42.20 PM.jpeg')

# %%
img_res=mpimg.imread('/content/WhatsApp Image 2022-02-28 at 10.42.20 PM.jpeg')
img_resplot=plt.imshow(img)
plt.show()

# %%
print(img_res.shape)
# Out:
# (300, 300, 3)

# %%
# converting RGB image to GRAY scale image using opencv
import cv2

# %%
img = cv2.imread('/content/WhatsApp Image 2022-02-28 at 10.42.20 PM.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (300, 300, 3)

# %%
bluescale_image = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
grayscale_image.shape
# Out:
# (200, 200)

# %%
#cv2.imshow() will display the iamge but this will not be allowed in colab.
from google.colab.patches import cv2_imshow

# %%
#displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7F0F46C33CD0>

# %%
#saving the grayscale image
cv2.imwrite('/content/WhatsApp Image 2022-02-28 at 10.42.20 PM.jpeg',grayscale_image)
# Out:
# True
